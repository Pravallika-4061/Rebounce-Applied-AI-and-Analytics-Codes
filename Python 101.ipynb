# %% [markdown]
# <a href="https://colab.research.google.com/github/Pravallika-4061/Rebounce-Applied-AI-and-Analytics-Codes/blob/main/Python%20101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("MP1 starting")
# Out:
# MP1 starting

# %%
name = "Pravallika"
city = "Eluru"
year_of_birth = 2002
current_year = 2026
age = current_year - year_of_birth

# %%
print("Hi,I'm",name,"from",city,".This year I turn",age,".")
# Out:
# Hi,I'm Pravallika from Eluru .This year I turn 24 .

# %%
#storing the amount and exchange rate
inr_amount=75000
exchange_rate=1.75
#calculating the amount in yen
conversion_amount=inr_amount * exchange_rate
#printing the result
print("Rs 75000 converts to Yen",conversion_amount)
print(f"Rs 75000 converts to Yen {conversion_amount:.2f}" )
# Out:
# Rs 75000 converts to Yen 131250.0
# Rs 75000 converts to Yen 131250.00
